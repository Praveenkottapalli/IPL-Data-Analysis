# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# To import the csv file 

deliveries_data=pd.read_csv("C:/Users/Praveen/Desktop/Codebasics/pyhton/ipl analysis/IPL Ball-by-Ball 2008-2020.csv")
deliveries_data
# Out:
#              id  inning  over  ball      batsman  non_striker  \
# 0        335982       1     6     5   RT Ponting  BB McCullum
# 1        335982       1     6     6  BB McCullum   RT Ponting
# 2        335982       1     7     1  BB McCullum   RT Ponting
# 3        335982       1     7     2  BB McCullum   RT Ponting
# 4        335982       1     7     3   RT Ponting  BB McCullum
# ...         ...     ...   ...   ...          ...          ...
# 193463  1237181       1    12     5      RR Pant      SS Iyer
# 193464  1237181       1    12     6      RR Pant      SS Iyer
# 193465  1237181       1    13     1      RR Pant      SS Iyer
# 193466  1237181       1    13     2      RR Pant      SS Iyer
# 193467  1237181       1    13     3      SS Iyer      RR Pant
#
#                  bowler  batsman_runs  extra_runs  total_runs  non_boundary  \
# 0             AA Noffke             1           0           1             0
# ...

# %%
# To import the csv file 
match_data=pd.read_csv(r"C:\Users\Praveen\Desktop\Codebasics\pyhton\ipl analysis\IPL Matches 2008-2020.csv")
match_data
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
match_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
match_data.describe()
# Out:
#                  id  neutral_venue  result_margin
# count  8.160000e+02     816.000000     799.000000
# mean   7.563496e+05       0.094363      17.321652
# std    3.058943e+05       0.292512      22.068427
# min    3.359820e+05       0.000000       1.000000
# 25%    5.012278e+05       0.000000       6.000000
# 50%    7.292980e+05       0.000000       8.000000
# 75%    1.082626e+06       0.000000      19.500000
# max    1.237181e+06       1.000000     146.000000

# %%
match_data.shape         #how many rows and cloumns
# Out:
# (816, 17)

# %%
match_data.isnull().sum()
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
match_data.drop('method',axis=1)
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
match_data["city"].isnull().sum()
# Out:
# 13

# %%
match_data[match_data["city"].isnull()][["id", "date", "team1", "team2", "venue","city"]]
# Out:
#          id        date                        team1  \
# 399  729281  2014-04-17             Delhi Daredevils
# 402  729287  2014-04-19  Royal Challengers Bangalore
# 403  729289  2014-04-19        Kolkata Knight Riders
# 404  729291  2014-04-20             Rajasthan Royals
# 406  729295  2014-04-22              Kings XI Punjab
# 407  729297  2014-04-23             Rajasthan Royals
# 408  729299  2014-04-24  Royal Challengers Bangalore
# 409  729301  2014-04-25          Sunrisers Hyderabad
# 410  729303  2014-04-25          Chennai Super Kings
# 413  729309  2014-04-27             Delhi Daredevils
# 414  729311  2014-04-27          Sunrisers Hyderabad
# 415  729313  2014-04-28              Kings XI Punjab
# 417  729317  2014-04-30               Mumbai Indians
#
#                            team2                                venue city
# 399  Royal Challengers Bangalore              Sharjah Cricket Stadium  NaN
# ...

# %%
match_data["city"].fillna("Dubai", inplace=True)

# %%
match_data
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %% [markdown]
# match_data.isnull("city").sum()

# %%
match_data["city"].isnull().sum()
# Out:
# 0

# %%
match_data.isnull().sum()
# Out:
# id                   0
# city                 0
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
match_data[match_data["winner"].isnull()]["winner"]
# Out:
# 241    NaN
# 486    NaN
# 511    NaN
# 744    NaN
# Name: winner, dtype: object

# %%
match_data["winner"].fillna("No Result", inplace=True)

# %%
match_data.isnull().sum()
# Out:
# id                   0
# city                 0
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               0
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
v=pd.merge(match_data,deliveries_data,on="id")
v
# Out:
#              id       city        date player_of_match  \
# 0        335982  Bangalore  2008-04-18     BB McCullum
# 1        335982  Bangalore  2008-04-18     BB McCullum
# 2        335982  Bangalore  2008-04-18     BB McCullum
# 3        335982  Bangalore  2008-04-18     BB McCullum
# 4        335982  Bangalore  2008-04-18     BB McCullum
# ...         ...        ...         ...             ...
# 193463  1237181      Dubai  2020-11-10        TA Boult
# 193464  1237181      Dubai  2020-11-10        TA Boult
# 193465  1237181      Dubai  2020-11-10        TA Boult
# 193466  1237181      Dubai  2020-11-10        TA Boult
# 193467  1237181      Dubai  2020-11-10        TA Boult
#
#                                       venue  neutral_venue  \
# 0                     M Chinnaswamy Stadium              0
# 1                     M Chinnaswamy Stadium              0
# 2                     M Chinnaswamy Stadium              0
# 3                     M Chinnaswamy Stadium              0
# ...

# %% [markdown]
# virat kohli Performance Analysis

# %%
filt=deliveries_data["batsman"]=='V Kohli'
filt
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 193463    False
# 193464    False
# 193465    False
# 193466    False
# 193467    False
# Name: batsman, Length: 193468, dtype: bool

# %%
vk=deliveries_data[filt]  #vk=virat kohli
vk
# Out:
#              id  inning  over  ball  batsman non_striker          bowler  \
# 211      335982       2     1     2  V Kohli    W Jaffer        I Sharma
# 212      335982       2     1     3  V Kohli    W Jaffer        I Sharma
# 213      335982       2     1     4  V Kohli    W Jaffer        I Sharma
# 216      335982       2     2     1  V Kohli    W Jaffer        AB Dinda
# 217      335982       2     2     2  V Kohli    W Jaffer        AB Dinda
# ...         ...     ...   ...   ...      ...         ...             ...
# 192772  1237178       1     0     5  V Kohli  D Padikkal  Sandeep Sharma
# 192773  1237178       1     0     6  V Kohli  D Padikkal  Sandeep Sharma
# 192774  1237178       1     1     1  V Kohli  D Padikkal       JO Holder
# 192775  1237178       1     1     2  V Kohli  D Padikkal       JO Holder
# 192892  1237178       1     0     4  V Kohli  D Padikkal  Sandeep Sharma
#
#         batsman_runs  extra_runs  total_runs  non_boundary  is_wicket  \
# ...

# %%
vk.columns
# Out:
# Index(['id', 'inning', 'over', 'ball', 'batsman', 'non_striker', 'bowler',
#        'batsman_runs', 'extra_runs', 'total_runs', 'non_boundary', 'is_wicket',
#        'dismissal_kind', 'player_dismissed', 'fielder', 'extras_type',
#        'batting_team', 'bowling_team'],
#       dtype='object')

# %%
# how many times vk got out in different modes 
vk['dismissal_kind'].value_counts()
# Out:
# caught               105
# bowled                30
# run out               15
# lbw                    7
# stumped                3
# caught and bowled      3
# Name: dismissal_kind, dtype: int64

# %%
# single runs scored by vk
len(vk[vk['batsman_runs']==1])
# Out:
# 1919

# %%
# double runs scored by vk
len(vk[vk['batsman_runs']==2])*2
# Out:
# 692

# %%
# three runs scored by vk at a time
len(vk[vk['batsman_runs']==3])*3
# Out:
# 39

# %%
#how many four vk scored
len(vk[vk['batsman_runs']==4])*4
# Out:
# 2016

# %%
#how many sixes vk scored
len(vk[vk['batsman_runs']==6])*6
# Out:
# 1212

# %%
runs=[721,234,21,1184,174]
labels=[1,2,3,4,6]

# %%
plt.bar(labels,runs,color='blue')

plt.title("Bar Chart of Runs",size=20)
plt.xlabel('labels')
plt.ylabel('runs')
plt.show()

# %%
# top 10 scorers in the tournament

top_run_scorers = deliveries_data.groupby("batsman")["batsman_runs"].sum().reset_index()
top_run_scorers = top_run_scorers.sort_values(by="batsman_runs", ascending=False)
top_run_scorers.head(10)
# Out:
#             batsman  batsman_runs
# 505         V Kohli          5878
# 438        SK Raina          5368
# 116       DA Warner          5254
# 379       RG Sharma          5230
# 407        S Dhawan          5197
# 24   AB de Villiers          4849
# 96         CH Gayle          4772
# 301        MS Dhoni          4632
# 398      RV Uthappa          4607
# 154       G Gambhir          4217

# %%
# Count valid dismissals (excluding "run out" as it is not credited to a bowler)
valid_dismissals = ["caught", "bowled", "lbw", "stumped", "caught and bowled", "hit wicket"]

# Filter out valid dismissals and count wickets per bowler
top_wicket_takers = deliveries_data[deliveries_data["dismissal_kind"].isin(valid_dismissals)].groupby("bowler").size().reset_index(name="wickets")

# Sort in descending order to get top wicket takers
top_wicket_takers = top_wicket_takers.sort_values(by="wickets", ascending=False)

# Display top 10 wicket takers
print(top_wicket_takers.head(10))
# Out:
#               bowler  wickets
# 297       SL Malinga      170
# 5           A Mishra      160
# 235        PP Chawla      156
# 85          DJ Bravo      153
# 115  Harbhajan Singh      150
# 240         R Ashwin      138
# 50           B Kumar      136
# 304        SP Narine      127
# 357        YS Chahal      121
# 338         UT Yadav      119

# %%
# Count total runs conceded per bowler
bowler_runs = deliveries_data.groupby("bowler")["total_runs"].sum().reset_index()

# Count total balls bowled per bowler
bowler_balls = deliveries_data.groupby("bowler")["ball"].count().reset_index()

# Merge the two dataframes
bowler_stats = pd.merge(bowler_runs, bowler_balls, on="bowler")

# Convert balls into overs (1 over = 6 balls)
bowler_stats["overs"] = bowler_stats["ball"] // 6  # Ignore incomplete overs

# Calculate economy rate
bowler_stats["economy_rate"] = bowler_stats["total_runs"] / bowler_stats["overs"]

# Sort by best economy (ascending order)
bowler_stats = bowler_stats.sort_values(by="economy_rate")
print(bowler_stats.head(10))  # Top 10 economical bowlers
# Out:
#             bowler  total_runs  ball  overs  economy_rate
# 254       NB Singh          18    25      4      4.500000
# 34       AM Rahane           5     6      1      5.000000
# 42          AS Roy          11    15      2      5.500000
# 104    DJ Thornely          40    44      7      5.714286
# 213       M Manhas          42    42      7      6.000000
# 364      SS Mundhe           6     7      1      6.000000
# 202  LA Carseldine           6     7      1      6.000000
# 379  Sohail Tanvir         275   265     44      6.250000
# 1       A Chandila         245   234     39      6.282051
# 312    Rashid Khan        1573  1490    248      6.342742

# %%
match_data['season'] =pd.to_datetime(match_data['date']).dt.year    # we added new column as season
match_data.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2',
#        'season'],
#       dtype='object')

# %%
match_data
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
season_toss_count=match_data.groupby(['season','toss_decision']).size().reset_index().rename(columns={0:'count'})
season_toss_count
# Out:
#     season toss_decision  count
# 0     2008           bat     26
# 1     2008         field     32
# 2     2009           bat     35
# 3     2009         field     22
# 4     2010           bat     39
# 5     2010         field     21
# 6     2011           bat     25
# 7     2011         field     48
# 8     2012           bat     37
# 9     2012         field     37
# 10    2013           bat     45
# 11    2013         field     31
# 12    2014           bat     19
# 13    2014         field     41
# 14    2015           bat     25
# 15    2015         field     34
# 16    2016           bat     11
# 17    2016         field     49
# 18    2017           bat     11
# 19    2017         field     48
# 20    2018           bat     10
# 21    2018         field     50
# 22    2019           bat     10
# 23    2019         field     50
# 24    2020           bat     27
# 25    2020         field     33

# %%
plt.bar(season_toss_count['season'], season_toss_count['count'], color='blue')
# Out:
# <BarContainer object of 26 artists>

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='season', y='count', hue='toss_decision', data=season_toss_count)
# Out:
# <AxesSubplot:xlabel='season', ylabel='count'>

# %% [markdown]
# Analysis whether winning toss implies winning game or not

# %%
match_data.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2',
#        'season'],
#       dtype='object')

# %%
match_data[['team1', 'team2', 'toss_winner', 'winner']]
# Out:
#                            team1                        team2  \
# 0    Royal Challengers Bangalore        Kolkata Knight Riders
# 1                Kings XI Punjab          Chennai Super Kings
# 2               Delhi Daredevils             Rajasthan Royals
# 3                 Mumbai Indians  Royal Challengers Bangalore
# 4          Kolkata Knight Riders              Deccan Chargers
# ..                           ...                          ...
# 811  Royal Challengers Bangalore               Mumbai Indians
# 812               Mumbai Indians               Delhi Capitals
# 813  Royal Challengers Bangalore          Sunrisers Hyderabad
# 814               Delhi Capitals          Sunrisers Hyderabad
# 815               Delhi Capitals               Mumbai Indians
#
#                      toss_winner                       winner
# 0    Royal Challengers Bangalore        Kolkata Knight Riders
# 1            Chennai Super Kings          Chennai Super Kings
# ...

# %%
match_data['toss_win_match_win']=np.where(match_data['toss_winner']==match_data['winner'],'Yes','No')
match_data
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
match_data['toss_win_match_win'].value_counts().index
# Out:
# Index(['Yes', 'No'], dtype='object')

# %%
match_data['toss_win_match_win'].value_counts().values
# Out:
# array([418, 398], dtype=int64)

# %%
labels=match_data['toss_win_match_win'].value_counts().index
values=match_data['toss_win_match_win'].value_counts().values
plt.pie(values, labels=labels, autopct='%1.1f%%', colors=['skyblue', 'orange'])
plt.grid()
plt.show()

# %% [markdown]
# ---------------------

# %% [markdown]
# Number of times team won the tournament

# %%
df_2018=match_data[match_data['season']==2018]

# %%
df_2018['winner'].tail(1).values
# Out:
# array(['Chennai Super Kings'], dtype=object)

# %%
winner_team={}
for year in sorted (match_data['season'].unique()):
    current_year=match_data[match_data['season']==year]
    winner_team[year]=current_year['winner'].tail(1).values[0]

# %%
winner_team
# Out:
# {2008: 'Rajasthan Royals',
#  2009: 'Deccan Chargers',
#  2010: 'Chennai Super Kings',
#  2011: 'Chennai Super Kings',
#  2012: 'Kolkata Knight Riders',
#  2013: 'Mumbai Indians',
#  2014: 'Kolkata Knight Riders',
#  2015: 'Mumbai Indians',
#  2016: 'Sunrisers Hyderabad',
#  2017: 'Mumbai Indians',
#  2018: 'Chennai Super Kings',
#  2019: 'Mumbai Indians',
#  2020: 'Mumbai Indians'}

# %%
winner_team.values()
# Out:
# dict_values(['Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings', 'Chennai Super Kings', 'Kolkata Knight Riders', 'Mumbai Indians', 'Kolkata Knight Riders', 'Mumbai Indians', 'Sunrisers Hyderabad', 'Mumbai Indians', 'Chennai Super Kings', 'Mumbai Indians', 'Mumbai Indians'])

# %%
from collections import Counter

# %%
Counter(winner_team.values())
# Out:
# Counter({'Rajasthan Royals': 1,
#          'Deccan Chargers': 1,
#          'Chennai Super Kings': 3,
#          'Kolkata Knight Riders': 2,
#          'Mumbai Indians': 5,
#          'Sunrisers Hyderabad': 1})

# %% [markdown]
# ************************

# %% [markdown]
# comparison between the teams

# %%
match_data[['team1','team2']]
# Out:
#                            team1                        team2
# 0    Royal Challengers Bangalore        Kolkata Knight Riders
# 1                Kings XI Punjab          Chennai Super Kings
# 2               Delhi Daredevils             Rajasthan Royals
# 3                 Mumbai Indians  Royal Challengers Bangalore
# 4          Kolkata Knight Riders              Deccan Chargers
# ..                           ...                          ...
# 811  Royal Challengers Bangalore               Mumbai Indians
# 812               Mumbai Indians               Delhi Capitals
# 813  Royal Challengers Bangalore          Sunrisers Hyderabad
# 814               Delhi Capitals          Sunrisers Hyderabad
# 815               Delhi Capitals               Mumbai Indians
#
# [816 rows x 2 columns]

# %%
matches_played=match_data['team1'].value_counts()+ match_data['team2'].value_counts()
df_matchs_played=matches_played.reset_index()
df_matchs_played.columns=['team_name','matches_played']
df_matchs_played
# Out:
#                       team_name  matches_played
# 0           Chennai Super Kings             178
# 1               Deccan Chargers              75
# 2                Delhi Capitals              33
# 3              Delhi Daredevils             161
# 4                 Gujarat Lions              30
# 5               Kings XI Punjab             190
# 6          Kochi Tuskers Kerala              14
# 7         Kolkata Knight Riders             192
# 8                Mumbai Indians             203
# 9                 Pune Warriors              46
# 10             Rajasthan Royals             161
# 11       Rising Pune Supergiant              16
# 12      Rising Pune Supergiants              14
# 13  Royal Challengers Bangalore             195
# 14          Sunrisers Hyderabad             124

# %%
wins=match_data['winner'].value_counts().reset_index()
wins.columns=['team_name','wins']
wins
# Out:
#                       team_name  wins
# 0                Mumbai Indians   120
# 1           Chennai Super Kings   106
# 2         Kolkata Knight Riders    99
# 3   Royal Challengers Bangalore    91
# 4               Kings XI Punjab    88
# 5              Rajasthan Royals    81
# 6              Delhi Daredevils    67
# 7           Sunrisers Hyderabad    66
# 8               Deccan Chargers    29
# 9                Delhi Capitals    19
# 10                Gujarat Lions    13
# 11                Pune Warriors    12
# 12       Rising Pune Supergiant    10
# 13         Kochi Tuskers Kerala     6
# 14      Rising Pune Supergiants     5
# 15                    No Result     4

# %%
total_matches_won=pd.merge(df_matchs_played,wins,on='team_name')
total_matches_won
# Out:
#                       team_name  matches_played  wins
# 0           Chennai Super Kings             178   106
# 1               Deccan Chargers              75    29
# 2                Delhi Capitals              33    19
# 3              Delhi Daredevils             161    67
# 4                 Gujarat Lions              30    13
# 5               Kings XI Punjab             190    88
# 6          Kochi Tuskers Kerala              14     6
# 7         Kolkata Knight Riders             192    99
# 8                Mumbai Indians             203   120
# 9                 Pune Warriors              46    12
# 10             Rajasthan Royals             161    81
# 11       Rising Pune Supergiant              16    10
# 12      Rising Pune Supergiants              14     5
# 13  Royal Challengers Bangalore             195    91
# 14          Sunrisers Hyderabad             124    66

# %%
plt.figure(figsize=(30,15))

ax = sns.barplot(x="team_name", y="matches_played", data=total_matches_won, color='skyblue', label="matches_played")
sns.barplot(x="team_name", y="wins", data=total_matches_won, color='orange', label="wins")
plt.title('matches won out of total matches_played',size=30)
plt.show()                         # orange is the matches won , skyblue is the matches played

# %%
top_run_scorers = deliveries_data.groupby("batsman")["batsman_runs"].sum().reset_index()
top_run_scorers = top_run_scorers.sort_values(by="batsman_runs", ascending=False)
top_run_scorers.head(10)
# Out:
#             batsman  batsman_runs
# 505         V Kohli          5878
# 438        SK Raina          5368
# 116       DA Warner          5254
# 379       RG Sharma          5230
# 407        S Dhawan          5197
# 24   AB de Villiers          4849
# 96         CH Gayle          4772
# 301        MS Dhoni          4632
# 398      RV Uthappa          4607
# 154       G Gambhir          4217

# %%
p=match_data.groupby("season").sum().reset_index()['season']
q=match_data['id']
top_run_scorers = deliveries_data.groupby("batsman")["batsman_runs"].sum().reset_index()

# %%
merged_data = pd.merge(deliveries_data, match_data[['id', 'season']], on='id', how='left')
season_batsman_runs=merged_data.groupby(['season','batsman'])['batsman_runs'].sum().reset_index()
season_batsman_runs
# Out:
#       season            batsman  batsman_runs
# 0       2008           A Chopra            42
# 1       2008           A Kumble            13
# 2       2008           A Mishra            37
# 3       2008           A Mukund             0
# 4       2008            A Nehra             3
# ...      ...                ...           ...
# 1941    2020           VR Aaron             1
# 1942    2020            WP Saha           214
# 1943    2020  Washington Sundar           111
# 1944    2020        YBK Jaiswal            40
# 1945    2020          YS Chahal             1
#
# [1946 rows x 3 columns]

# %%
top_10_batsmen_per_season = season_batsman_runs.sort_values(by=['season', 'batsman_runs'], ascending=[True, False]).groupby('season').head(10).reset_index(drop=True)
top_10_batsmen_per_season
# Out:
#      season         batsman  batsman_runs
# 0      2008        SE Marsh           616
# 1      2008       G Gambhir           534
# 2      2008   ST Jayasuriya           514
# 3      2008       SR Watson           472
# 4      2008        GC Smith           441
# ..      ...             ...           ...
# 125    2020       Q de Kock           503
# 126    2020        SA Yadav           480
# 127    2020      D Padikkal           473
# 128    2020         V Kohli           466
# 129    2020  AB de Villiers           454
#
# [130 rows x 3 columns]

# %%
top_10_batsmen_2018 = top_10_batsmen_per_season[top_10_batsmen_per_season['season'] == 2018]
top_10_batsmen_2018.head(10)
# Out:
#      season        batsman  batsman_runs
# 100    2018  KS Williamson           735
# 101    2018        RR Pant           684
# 102    2018       KL Rahul           659
# 103    2018      AT Rayudu           602
# 104    2018      SR Watson           555
# 105    2018     JC Buttler           548
# 106    2018        V Kohli           530
# 107    2018       SA Yadav           512
# 108    2018     KD Karthik           498
# 109    2018       S Dhawan           497

# %%
top_10_batsmen_2019 = top_10_batsmen_per_season[top_10_batsmen_per_season['season'] == 2019]
top_10_batsmen_2019
# Out:
#      season      batsman  batsman_runs
# 110    2019    DA Warner           692
# 111    2019     KL Rahul           593
# 112    2019    Q de Kock           529
# 113    2019     S Dhawan           521
# 114    2019   AD Russell           510
# 115    2019     CH Gayle           490
# 116    2019      RR Pant           488
# 117    2019      V Kohli           464
# 118    2019      SS Iyer           463
# 119    2019  JM Bairstow           445

# %%
top_10_batsmen_2020 = top_10_batsmen_per_season[top_10_batsmen_per_season['season'] == 2020]
top_10_batsmen_2020
# Out:
#      season         batsman  batsman_runs
# 120    2020        KL Rahul           670
# 121    2020        S Dhawan           618
# 122    2020       DA Warner           548
# 123    2020         SS Iyer           519
# 124    2020    Ishan Kishan           516
# 125    2020       Q de Kock           503
# 126    2020        SA Yadav           480
# 127    2020      D Padikkal           473
# 128    2020         V Kohli           466
# 129    2020  AB de Villiers           454
